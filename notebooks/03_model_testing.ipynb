# %%
from app.models.assessment import Assessment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from app.models.assessment import Assessment
#
# ModuleNotFoundError: No module named 'app'

# %%
sample = {
    "entity_id": "123",
    "name": "Python Test",
    "description": "Tests Python",
    "duration": "30 minutes",
    "languages": ["English"],
    "job_levels": ["Professional"],
    "keys": ["Knowledge & Skills"],
    "remote": "yes",
    "adaptive": "no",
    "link": "https://example.com"
}

# %%
assessment = Assessment(**sample)

assessment
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 assessment = Assessment(**sample)
#       3 assessment
#
# NameError: name 'Assessment' is not defined

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Dell\Desktop\DATA ANALYTICS\Projects\SHL_AI_Recommender\notebooks

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# C:\Users\Dell\Desktop\DATA ANALYTICS\Projects\SHL_AI_Recommender\notebooks

# %%
import sys
from pathlib import Path

print("Current Working Directory:")
print(Path.cwd())

print("\nFirst 5 sys.path entries:")
for p in sys.path[:5]:
    print(p)
# Out:
# Current Working Directory:
# C:\Users\Dell\Desktop\DATA ANALYTICS\Projects\SHL_AI_Recommender\notebooks
#
# First 5 sys.path entries:
# C:\Users\Dell\anaconda3\envs\ml\python310.zip
# C:\Users\Dell\anaconda3\envs\ml\DLLs
# C:\Users\Dell\anaconda3\envs\ml\lib
# C:\Users\Dell\anaconda3\envs\ml

# %%
python -m pip install -e .
# Out:
#   Cell In[21], line 1
#     python -m pip install -e .
#               ^
# SyntaxError: invalid syntax

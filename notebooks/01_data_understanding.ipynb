# %%
import json
import pandas as pd
from pathlib import Path

# %%
DATA_PATH = Path("../data/raw/shl_product_catalog.json")

DATA_PATH.exists()
# Out:
# True

# %%
try:
    with open(DATA_PATH, "r", encoding="utf-8") as f:
        data = json.load(f)

    print("✅ JSON loaded successfully!")
    print(f"Total records: {len(data)}")

except json.JSONDecodeError as e:
    print("❌ JSON is invalid")
    print(e)
# Out:
# ❌ JSON is invalid
# Invalid control character at: line 4795 column 24 (char 197732)

# %%
with open(DATA_PATH, "r", encoding="utf-8") as f:
    lines = f.readlines()

# Show a few lines around the error
for i in range(4790, 4801):
    print(f"{i+1}: {lines[i]}", end="")
# Out:
# 4791:     ]
# 4792:   },
# 4793:   {
# 4794:     "entity_id": "4207",
# 4795:     "name": "Microsoft
# 4796:     365 (New)",
# 4797:     "link": "https://www.shl.com/products/product-catalog/view/microsoft-excel-365-new/",
# 4798:     "scraped_at": "2026-05-08T10:55:10.466416+00:00",
# 4799:     "job_levels": [
# 4800:       "Entry-Level"
# 4801:     ],
